# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://aws:****@atbay-170254541430.d.codeartifact.us-east-1.amazonaws.com/pypi/atbay/simple/
# ...
#   Attempting uninstall: Flask-Cors
#     Found existing installation: Flask-Cors 4.0.1
#     Uninstalling Flask-Cors-4.0.1:
#       Successfully uninstalled Flask-Cors-4.0.1
# ...
# WARNING: You are using pip version 20.2.3; however, version 25.0 is available.
# You should consider upgrading via the '/Users/natalicutic/masterschols/AWS_grocery/tmp-venv/bin/python3 -m pip install --upgrade pip' command.
